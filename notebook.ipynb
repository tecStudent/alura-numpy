# %% [markdown]
# ## Baixando o material da aula

# %% [markdown]
# - Instalando a bilioteca wget
# - Fazendo o download do arquivo numpy-dados.zip pelo link
# - Descompactando arquivos baixados
#
# ### Referências:
# - Bilioteca wget : https://pypi.org/project/wget/
# - Funcionamento comando wget no linux : https://www.hostgator.com.br/blog/como-usar-o-comando-wget-do-linux/
# - Para descompactar um arquivo : https://programadorviking.com.br/python-zipfile/

# %%
# !pip install wget

# %%
# import wget

# url = 'https://github.com/alura-cursos/numpy/archive/refs/heads/dados.zip'

# filename = wget.download(url)

# %%
import os
from zipfile import ZipFile

files = os.listdir()

data = [file for  file in files if ".zip" in file]

zip = ZipFile(data[0], 'r')
zip.extractall()
zip.close()

# %% [markdown]
# # Primeiro módulo - conectando e carregando a base de dados

# %% [markdown]
# - Conectando ao arquivo apples_ts.csv
# - Limitando as colunas para não pegar strig
# - Carregar as informações numa variavel
# - Funções para obter dimensões das informações

# %%
import numpy as np

# %%
array_columns = np.arange(1,88,1)
# primeiro parametro de onde começa o array
# segundo parametro o total de itens mais 1
# terceiro parametro de quanto em quanto aumenta o array

# %%
dado = np.loadtxt('./numpy-dados/apples_ts.csv',delimiter=',',usecols=array_columns)
dado
# Out:
# array([[  1.2013,   2.2013,   3.2013,   4.2013,   5.2013,   6.2013,
#           7.2013,   8.2013,   9.2013,  10.2013,  11.2013,  12.2013,
#           1.2014,   2.2014,   3.2014,   4.2014,   5.2014,   6.2014,
#           7.2014,   8.2014,   9.2014,  10.2014,  11.2014,  12.2014,
#           1.2015,   2.2015,   3.2015,   4.2015,   5.2015,   6.2015,
#           7.2015,   8.2015,   9.2015,  10.2015,  11.2015,  12.2015,
#           1.2016,   2.2016,   3.2016,   4.2016,   5.2016,   6.2016,
#           7.2016,   8.2016,   9.2016,  10.2016,  11.2016,  12.2016,
#           1.2017,   2.2017,   3.2017,   4.2017,   5.2017,   6.2017,
#           7.2017,   8.2017,   9.2017,  10.2017,  11.2017,  12.2017,
#           1.2018,   2.2018,   3.2018,   4.2018,   5.2018,   6.2018,
#           7.2018,   8.2018,   9.2018,  10.2018,  11.2018,  12.2018,
#           1.2019,   2.2019,   3.2019,   4.2019,   5.2019,   6.2019,
#           7.2019,   8.2019,   9.2019,  10.2019,  11.2019,  12.2019,
# ...

# %%
# retorna o número de dimensões das informações
dado.ndim
# Out:
# 2

# %%
# retorna a quantidade de informações dentro de um arry
dado.size
# Out:
# 522

# %%
# retorna o número de elementos em cada dimensão
dado.shape
# Out:
# (6, 87)

# %%
# troca as linhas por colunas para vizualizar melhor 
dados_transposto = dado.T

# %% [markdown]
# # Segundo módulo - exploração dos dados

# %% [markdown]
# - Separando as informações em arrays
# - Criando uma vizualização
# - Tratando valores Nan

# %%
# separando as datas
datas = dados_transposto[:,0]

# %%
# separando os preços 
precos = dados_transposto[:,1:6]

# %%
# importando matplotlib para vizualizar os dados
import matplotlib.pyplot as plt

# %%
plt.plot(datas,precos[:,0])

# %%
# gerando um range de números para conseguir vizualizar 
datas = np.arange(1, 88)

# %%
plt.plot(datas,precos[:,0])

# %%
# passando um nome para os preços
Moscow = precos[:,0]
Kaliningrad = precos[:,1]
Petersburg = precos[:,2]
Krasnodar = precos[:,3]
Ekaterinburg = precos[:,4]

# %%
Moscow
# Out:
# array([ 79.72,  81.08,  79.68,  79.8 ,  80.63,  80.8 ,  80.28,  78.99,
#         76.77,  76.09,  76.36,  77.16,  77.5 ,  79.03,  80.28,  80.05,
#         78.11,  76.9 ,  77.68,  76.05,  75.53,  73.39,  78.36,  89.16,
#        105.43, 104.82, 101.15,  98.63,  99.96,  97.29,  98.64, 104.26,
#        102.63,  98.64,  97.17,  98.09, 103.07, 110.26, 110.84, 112.28,
#        111.1 , 110.06, 113.7 , 112.88, 102.08,  95.54,  91.33,  89.99,
#         91.44,  93.51,  93.6 ,  93.78,  98.91, 121.76, 129.6 , 127.9 ,
#        114.55, 101.88,  99.09, 103.35, 106.58, 108.  , 114.95, 121.17,
#        122.48, 127.58, 131.89, 129.36, 104.26,  93.45,  92.93,  96.15,
#         99.1 , 103.  , 103.31, 103.01, 107.37, 116.91, 125.29, 123.94,
#        113.03, 102.19,  97.83, 101.07, 103.44, 108.23, 110.28])

# %%
# Separando os valores por anos
Moscow_ano1 = Moscow[0:12] 
Moscow_ano2 = Moscow[12:24]
Moscow_ano3 = Moscow[24:36]
Moscow_ano4 = Moscow[36:48]

# %%
# Mostra um grafico em relação com o ano um
plt.plot(np.arange(1,13,1), Moscow_ano1)

# %%
# Mostra um grafico mostrando todos os anos
plt.plot(np.arange(1,13,1), Moscow_ano1)
plt.plot(np.arange(1,13,1), Moscow_ano2)
plt.plot(np.arange(1,13,1), Moscow_ano3)
plt.plot(np.arange(1,13,1), Moscow_ano4)
# adicona uma legenda
plt.legend(['ano1', 'ano2', 'ano3', 'ano4'])

# %%
# A função serve para comparar se os arrays são iguais 
np.array_equal(Moscow_ano3, Moscow_ano4)
# Out:
# False

# %%
# Para saber se a distância é menor que 0.01
np.allclose(Moscow_ano3, Moscow_ano4,0.01)
# Out:
# False

# %%
np.allclose(Moscow_ano3, Moscow_ano4,10)
# Out:
# True

# %%
plt.plot(datas, Kaliningrad)

# %%
Kaliningrad
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
# Verificando quantos nan tem no intervalo
sum(np.isnan(Kaliningrad))
# Out:
# 1

# %%
# Gerando a média dos valores 3 e 5 para substituir o nan
np.mean([Kaliningrad[3],Kaliningrad[5]])
# Out:
# 49.17

# %%
# Substituindo o valor nan
Kaliningrad[4] = np.mean([Kaliningrad[3],Kaliningrad[5]])

# %%
plt.plot(datas, Kaliningrad)

# %%
np.mean(Moscow)
# Out:
# 98.79781609195402

# %%
np.mean(Kaliningrad)
# Out:
# 74.5506896551724

# %%
plt.plot(datas,Moscow)

# %% [markdown]
# y=ax+b

# %%
x= datas

# %%
y=2*x+80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 749.2329171225728

# %%
y=0.52*x+80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 110.48504740461489

# %%
np.linalg.norm(Moscow-y)
# Out:
# 110.48504740461489

# %% [markdown]
# - â = coeficiente angular;
# - n = número de elementos;
# - Y = Moscow;
# - X = datas.
#
# ![image.png](attachment:image.png)

# %%
Y = Moscow
X = datas
n = np.size(Moscow)

# %%
(n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2) - np.sum(X)**2)
# Out:
# 0.43520212145512926

# %%
a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2) - np.sum(X)**2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
b = np.mean(Y) - a*np.mean(X)

# %%
y= a*X+b

# %%
np.linalg.norm(Moscow-y)
# Out:
# 101.7969539992751

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)
plt.plot(41.5,41.5*a+b,'*r')

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)
plt.plot(41.5,41.5*a+b,'*r')
plt.plot(100,100*a+b,'*r')

# %%
np.random.randint(low=40,high=100,size=100)
# Out:
# array([97, 73, 54, 59, 72, 98, 79, 91, 41, 49, 96, 42, 44, 71, 62, 56, 41,
#        91, 57, 81, 50, 90, 84, 94, 43, 46, 84, 48, 66, 90, 48, 92, 91, 67,
#        85, 44, 53, 86, 63, 79, 85, 80, 59, 60, 59, 71, 63, 62, 80, 53, 66,
#        67, 77, 41, 49, 47, 64, 55, 65, 98, 63, 55, 48, 72, 73, 43, 73, 86,
#        43, 69, 58, 87, 99, 70, 71, 84, 71, 89, 57, 52, 49, 86, 46, 47, 94,
#        76, 79, 81, 72, 67, 77, 91, 57, 76, 85, 81, 65, 62, 55, 83])

# %%
np.random.uniform(low=0.1,high=0.9,size=100)
# Out:
# array([0.50672531, 0.23185458, 0.67974869, 0.19590846, 0.45592329,
#        0.61924134, 0.22344953, 0.84534998, 0.28093269, 0.63958826,
#        0.77663207, 0.25449621, 0.56335371, 0.33408112, 0.15701155,
#        0.71598402, 0.14718419, 0.64643498, 0.13904156, 0.60117915,
#        0.86625892, 0.46445981, 0.83567252, 0.57613207, 0.54400142,
#        0.42209058, 0.88784076, 0.15172572, 0.71304889, 0.66723911,
#        0.46831001, 0.6967599 , 0.68567747, 0.56332219, 0.61976232,
#        0.76448365, 0.77607711, 0.67491205, 0.18756351, 0.67110981,
#        0.83982127, 0.82753198, 0.19571873, 0.7943623 , 0.35226874,
#        0.10913316, 0.84603178, 0.46880334, 0.44866656, 0.66860386,
#        0.76137986, 0.21177731, 0.21865487, 0.5695349 , 0.898006  ,
#        0.58784832, 0.75919098, 0.41254524, 0.8240485 , 0.48720406,
#        0.59261192, 0.34989771, 0.12655273, 0.18452333, 0.75431888,
#        0.54701672, 0.50349224, 0.82502962, 0.18698432, 0.32951937,
# ...

# %%
coef_angulares = np.random.uniform(low=0.10,high=0.90,size=100)

# %%
for i in range(100):
    print(np.linalg.norm(Moscow-(coef_angulares[i]*X+b)))
# Out:
# 109.9692037638421
# 101.8171135608314
# 116.71456353047027
# 186.27414508938062
# 105.22363927365693
# 145.76219845894093
# 104.20897125044343
# 176.45900585347215
# 115.21427002142795
# 184.66361460885648
# 127.15993946998019
# 113.18655078041155
# 220.71878053896944
# 118.85030140216341
# 178.33129817852287
# 121.06712979265599
# 105.88762631481822
# 161.59437866903312
# 167.6826112551023
# 168.34980226900788
# 112.83372563688164
# 161.00301650712922
# 103.03007936047274
# 161.5342019966958
# 138.49293591267428
# 153.01886068092367
# 185.27026610469014
# 134.87461574283867
# 133.20703681041414
# 146.17147218597268
# 106.08536647695153
# 171.3800265931697
# 141.33456063979273
# 113.34220372658831
# 133.70262847105218
# 111.10082681124265
# 159.4168634582568
# 112.71326509175678
# 130.67393070275634
# 190.49501577496662
# 145.33711299575134
# 178.54241459654955
# 104.85646074390053
# 137.2997760381941
# 133.6943637918395
# 105.19144091964961
# 193.1845032938441
# 182.3943775040433
# ...

# %%
norma2 = np.array([])
for i in range(100):
    norma2 = np.append(norma2, np.linalg.norm(Moscow-(coef_angulares[i]*X+b)))

# %%
coef_angulares[1]
# Out:
# 0.439489581340036
